# %%
import pandas as pd

# %%
product_data_path = "data/digikala-products.csv" 
product_data = pd.read_csv(product_data_path, low_memory=False)
product_data
# Out:
#                id                                   title_fa  Rate  Rate_cnt  \
# 0         7096438               آبسلانگ مدل s5 بسته 250 عددی    90         4
# 1         2845119              آبسلانگ مدل M-1 بسته 400 عددی    84       217
# 2         6117745            آبسلانگ مدل m50 مجموعه 500 عددی    88        14
# 3         1912926                      استند ابسلانگ مدل S01    78        25
# 4         6335462         آبسلانگ نوری تسلامد مدل All-in-One    84        25
# ...           ...                                        ...   ...       ...
# 1283491   8745218               جعبه نگهدارنده دارو مدل چوبی    90        24
# 1283492   8159085      محفظه نگهداری قرص و پودر میوتنت مدل T    96         4
# 1283493   8137567      محفظه نگهداری قرص و پودر اسپرتر مدل S    70         2
# 1283494  11618907  محفظه نگهداری قرص و پودر مدل pill crusher     0         0
# 1283495  11606283   محفظه نگهداری قرص مدل GS-402P685-402P685    20         1
#
# ...

# %%
comment_data_path = "data/digikala-comments.csv" 
comment_data = pd.read_csv(comment_data_path, low_memory=False)
comment_data
# Out:
#                id                              title  \
# 0        53672599                     پیشنهاد نمیشود
# 1         9897229                       بسته بندی بد
# 2        38074516                           برس ریمل
# 3        18628562                      خوبه و خوشرنگ
# 4        53301258                         برس رنگ مو
# ...           ...                                ...
# 6156284  47614197                                NaN
# 6156285  46904341                                خوب
# 6156286  46883275                                NaN
# 6156287  46948635  پایه شارژر دسته بازی پلی استیشن 5
# 6156288  45814457               پایه شارژ کنترلر ps5
#
#                                                       body      created_at  \
# 0                                          به درد نمیخوره   23 شهریور 1402
# 1        می‌تونست به عنوان یه کالای فرهنگی بهتر بسته بن...     16 تیر 1399
# 2        بسته بندیش خوب بود\r\n کاربرد و کیفیتشم خیلی خ...   26 مرداد 1401
# ...
